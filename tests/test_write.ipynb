# %%
from bamboost import Manager, Simulation

db = Manager("test.writing")
sim = db["2a5f6373"]
for sim in db:
    sim: Simulation
    sim.update_metadata({"submitted": False})
# Out:
#          id notes     status  array_size  nb_processes  processors  submitted  \
# 0  f19134cf        Initiated       10000             8           1       True
# 1  2a5f6373        Initiated       10000             4           1       True
# 2  a2c906e9        Initiated       10000             1           1       True
# 3  4eda20ab        Initiated       10000             2           1       True
#
#             time_stamp
# 0  2024-01-03 16:27:19
# 1  2024-01-03 16:27:19
# 2  2024-01-03 16:27:19
# 3  2024-01-03 16:27:19

# %%
from test_write import run_test, create_test_run

db = Manager("test.writing")
create_test_run(db, 1, 1000)

# %%
from bamboost import Manager, Simulation

db = Manager("test")

print("Write 1 Array of size 20'000 x 20'000 \n")

for sim in db.sims(sort="nb_processes"):
    print("nb-processes: ", sim.parameters["nb_processes"])
    print("total time: ", sim.userdata["write_time_total"])
    # print("mpi times: ", sim.userdata["MPI"]["times"][:])
    print("---")
# Out:
# Write 1 Array of size 20'000 x 20'000
#
# nb-processes:  1
# total time:  7.499938488006592
# ---
# nb-processes:  2
# total time:  4.4952874183654785
# ---
# nb-processes:  4
# total time:  2.8199706077575684
# ---
# nb-processes:  8
# total time:  2.3333792686462402
# ---

# %%
sim = db[1]
sim.data["test"]
# Out:
# (1, 100000, 1)
